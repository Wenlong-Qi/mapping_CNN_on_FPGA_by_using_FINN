# %% [markdown]
# # MNIST_mAlexNet

# %%
import torch
from brevitas.nn import QuantConv2d, QuantIdentity, QuantMaxPool2d, QuantLinear,QuantDropout,QuantReLU
from brevitas.core.quant import QuantType
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torchsummary import summary

# %% [markdown]
# ## with stide

# %% [markdown]
# ## (28,28)

# %%
class mAlexNet_2D_28_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_2D_28_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv2d(in_channels=1,out_channels=16,kernel_size=3,
                                padding=1,bias=False)
        self.bn_1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn2 = nn.Conv2d(in_channels=16,out_channels=20,kernel_size=3,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm2d(20)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn3 = nn.Conv2d(in_channels=20,out_channels=30,kernel_size=3,stride=3,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm2d(30)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(1*1*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
class mAlexNet_1D_784_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_1D_784_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv1d(in_channels=1,out_channels=16,kernel_size=9,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm1d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn2 = nn.Conv1d(in_channels=16,out_channels=20,kernel_size=9,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm1d(20)
        self.maxpool2 = nn.MaxPool1d(kernel_size=6,stride=None)
        
        self.cnn3 = nn.Conv1d(in_channels=20,out_channels=30,kernel_size=7,stride=8,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm1d(30)
        self.maxpool3 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(1*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
mAlexNet_2D_28_s = mAlexNet_2D_28_s_Model()
summary(mAlexNet_2D_28_s,(1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 28, 28]             144
#               ReLU-2           [-1, 16, 28, 28]               0
#          MaxPool2d-3           [-1, 16, 14, 14]               0
#             Conv2d-4           [-1, 20, 12, 12]           2,880
#               ReLU-5           [-1, 20, 12, 12]               0
#          MaxPool2d-6             [-1, 20, 6, 6]               0
#             Conv2d-7             [-1, 30, 2, 2]           5,400
#               ReLU-8             [-1, 30, 2, 2]               0
#          MaxPool2d-9             [-1, 30, 1, 1]               0
#           Dropout-10                   [-1, 30]               0
#            Linear-11                   [-1, 60]           1,800
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 10,824
# Trainable params: 10,824
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.27
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.31
# ----------------------------------------------------------------
# D:\Anaconda3\envs\pytorch\lib\site-packages\torch\cuda\__init__.py:52: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 9010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
mAlexNet_1D_784_s = mAlexNet_1D_784_s_Model()
summary(mAlexNet_1D_784_s,(1,784))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1              [-1, 16, 776]             144
#               ReLU-2              [-1, 16, 776]               0
#          MaxPool1d-3              [-1, 16, 194]               0
#             Conv1d-4              [-1, 20, 186]           2,880
#               ReLU-5              [-1, 20, 186]               0
#          MaxPool1d-6               [-1, 20, 31]               0
#             Conv1d-7                [-1, 30, 4]           4,200
#               ReLU-8                [-1, 30, 4]               0
#          MaxPool1d-9                [-1, 30, 1]               0
#           Dropout-10                   [-1, 30]               0
#            Linear-11                   [-1, 60]           1,800
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 9,624
# Trainable params: 9,624
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.28
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.32
# ----------------------------------------------------------------
# D:\Anaconda3\envs\pytorch\lib\site-packages\torch\cuda\__init__.py:52: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 9010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# ## (42,42)

# %%
class mAlexNet_2D_42_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_2D_42_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv2d(in_channels=1,out_channels=16,kernel_size=3,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn2 = nn.Conv2d(in_channels=16,out_channels=20,kernel_size=3,
                                padding=1,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm2d(20)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn3 = nn.Conv2d(in_channels=20,out_channels=30,kernel_size=3,stride=3,
                                padding=1,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm2d(30)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(2*2*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
class mAlexNet_1D_1764_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_1D_1764_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv1d(in_channels=1,out_channels=16,kernel_size=9,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm1d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn2 = nn.Conv1d(in_channels=16,out_channels=20,kernel_size=8,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm1d(20)
        self.maxpool2 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn3 = nn.Conv1d(in_channels=20,out_channels=30,kernel_size=9,stride=9,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm1d(30)
        self.maxpool3 = nn.MaxPool1d(kernel_size=3,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(4*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
mAlexNet_2D_42_s = mAlexNet_2D_42_s_Model()
summary(mAlexNet_2D_42_s,(1,42,42))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 40, 40]             144
#               ReLU-2           [-1, 16, 40, 40]               0
#          MaxPool2d-3           [-1, 16, 20, 20]               0
#             Conv2d-4           [-1, 20, 20, 20]           2,880
#               ReLU-5           [-1, 20, 20, 20]               0
#          MaxPool2d-6           [-1, 20, 10, 10]               0
#             Conv2d-7             [-1, 30, 4, 4]           5,400
#               ReLU-8             [-1, 30, 4, 4]               0
#          MaxPool2d-9             [-1, 30, 2, 2]               0
#           Dropout-10                  [-1, 120]               0
#            Linear-11                   [-1, 60]           7,200
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 16,224
# Trainable params: 16,224
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.59
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.66
# ----------------------------------------------------------------

# %%
mAlexNet_1D_1764_s = mAlexNet_1D_1764_s_Model()
summary(mAlexNet_1D_1764_s,(1,1764))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1             [-1, 16, 1756]             144
#               ReLU-2             [-1, 16, 1756]               0
#          MaxPool1d-3              [-1, 16, 439]               0
#             Conv1d-4              [-1, 20, 432]           2,560
#               ReLU-5              [-1, 20, 432]               0
#          MaxPool1d-6              [-1, 20, 108]               0
#             Conv1d-7               [-1, 30, 12]           5,400
#               ReLU-8               [-1, 30, 12]               0
#          MaxPool1d-9                [-1, 30, 4]               0
#           Dropout-10                  [-1, 120]               0
#            Linear-11                   [-1, 60]           7,200
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 15,904
# Trainable params: 15,904
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.64
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.71
# ----------------------------------------------------------------

# %% [markdown]
# ## (56,56)

# %%
class mAlexNet_2D_56_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_2D_56_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv2d(in_channels=1,out_channels=16,kernel_size=3,
                                padding=1,bias=False)
        self.bn_1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn2 = nn.Conv2d(in_channels=16,out_channels=20,kernel_size=3,
                                padding=1,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm2d(20)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn3 = nn.Conv2d(in_channels=20,out_channels=30,kernel_size=3,stride=3,
                                padding=2,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm2d(30)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(3*3*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
class mAlexNet_1D_3136_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_1D_3136_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv1d(in_channels=1,out_channels=16,kernel_size=9,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm1d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn2 = nn.Conv1d(in_channels=16,out_channels=20,kernel_size=7,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm1d(20)
        self.maxpool2 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn3 = nn.Conv1d(in_channels=20,out_channels=30,kernel_size=8,stride=6,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm1d(30)
        self.maxpool3 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(8*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
mAlexNet_2D_56_s = mAlexNet_2D_56_s_Model()
summary(mAlexNet_2D_56_s,(1,56,56))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 56, 56]             144
#               ReLU-2           [-1, 16, 56, 56]               0
#          MaxPool2d-3           [-1, 16, 28, 28]               0
#             Conv2d-4           [-1, 20, 28, 28]           2,880
#               ReLU-5           [-1, 20, 28, 28]               0
#          MaxPool2d-6           [-1, 20, 14, 14]               0
#             Conv2d-7             [-1, 30, 6, 6]           5,400
#               ReLU-8             [-1, 30, 6, 6]               0
#          MaxPool2d-9             [-1, 30, 3, 3]               0
#           Dropout-10                  [-1, 270]               0
#            Linear-11                   [-1, 60]          16,200
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 25,224
# Trainable params: 25,224
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.15
# Params size (MB): 0.10
# Estimated Total Size (MB): 1.26
# ----------------------------------------------------------------

# %%
mAlexNet_1D_3136_s = mAlexNet_1D_3136_s_Model()
summary(mAlexNet_1D_3136_s,(1,3136))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1             [-1, 16, 3128]             144
#               ReLU-2             [-1, 16, 3128]               0
#          MaxPool1d-3              [-1, 16, 782]               0
#             Conv1d-4              [-1, 20, 776]           2,240
#               ReLU-5              [-1, 20, 776]               0
#          MaxPool1d-6              [-1, 20, 194]               0
#             Conv1d-7               [-1, 30, 32]           4,800
#               ReLU-8               [-1, 30, 32]               0
#          MaxPool1d-9                [-1, 30, 8]               0
#           Dropout-10                  [-1, 240]               0
#            Linear-11                   [-1, 60]          14,400
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 22,184
# Trainable params: 22,184
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.14
# Params size (MB): 0.08
# Estimated Total Size (MB): 1.24
# ----------------------------------------------------------------

# %% [markdown]
# ## (84,84)

# %%
class mAlexNet_2D_84_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_2D_84_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv2d(in_channels=1,out_channels=16,kernel_size=3,
                                padding=1,bias=False)
        self.bn_1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn2 = nn.Conv2d(in_channels=16,out_channels=20,kernel_size=3,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm2d(20)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn3 = nn.Conv2d(in_channels=20,out_channels=30,kernel_size=3,stride=3,
                                padding=2,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm2d(30)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(4*4*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
class mAlexNet_1D_7056_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_1D_7056_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv1d(in_channels=1,out_channels=16,kernel_size=9,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm1d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn2 = nn.Conv1d(in_channels=16,out_channels=20,kernel_size=8,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm1d(20)
        self.maxpool2 = nn.MaxPool1d(kernel_size=5,stride=None)
        
        self.cnn3 = nn.Conv1d(in_channels=20,out_channels=30,kernel_size=8,stride=7,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm1d(30)
        self.maxpool3 = nn.MaxPool1d(kernel_size=5,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(10*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
mAlexNet_2D_84_s = mAlexNet_2D_84_s_Model()
summary(mAlexNet_2D_84_s,(1,84,84))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 84, 84]             144
#               ReLU-2           [-1, 16, 84, 84]               0
#          MaxPool2d-3           [-1, 16, 42, 42]               0
#             Conv2d-4           [-1, 20, 40, 40]           2,880
#               ReLU-5           [-1, 20, 40, 40]               0
#          MaxPool2d-6           [-1, 20, 20, 20]               0
#             Conv2d-7             [-1, 30, 8, 8]           5,400
#               ReLU-8             [-1, 30, 8, 8]               0
#          MaxPool2d-9             [-1, 30, 4, 4]               0
#           Dropout-10                  [-1, 480]               0
#            Linear-11                   [-1, 60]          28,800
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 37,824
# Trainable params: 37,824
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 2.52
# Params size (MB): 0.14
# Estimated Total Size (MB): 2.70
# ----------------------------------------------------------------

# %%
mAlexNet_1D_7056_s = mAlexNet_1D_7056_s_Model()
summary(mAlexNet_1D_7056_s,(1,7056))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1             [-1, 16, 7048]             144
#               ReLU-2             [-1, 16, 7048]               0
#          MaxPool1d-3             [-1, 16, 1762]               0
#             Conv1d-4             [-1, 20, 1755]           2,560
#               ReLU-5             [-1, 20, 1755]               0
#          MaxPool1d-6              [-1, 20, 351]               0
#             Conv1d-7               [-1, 30, 50]           4,800
#               ReLU-8               [-1, 30, 50]               0
#          MaxPool1d-9               [-1, 30, 10]               0
#           Dropout-10                  [-1, 300]               0
#            Linear-11                   [-1, 60]          18,000
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 26,104
# Trainable params: 26,104
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 2.55
# Params size (MB): 0.10
# Estimated Total Size (MB): 2.68
# ----------------------------------------------------------------

# %% [markdown]
# ## (112,112)

# %%
class mAlexNet_2D_112_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_2D_112_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv2d(in_channels=1,out_channels=16,kernel_size=3,
                                padding=1,bias=False)
        self.bn_1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn2 = nn.Conv2d(in_channels=16,out_channels=20,kernel_size=3,
                                padding=1,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm2d(20)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn3 = nn.Conv2d(in_channels=20,out_channels=30,kernel_size=3,stride=3,
                                padding=1,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm2d(30)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(5*5*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
class mAlexNet_1D_12544_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_1D_12544_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv1d(in_channels=1,out_channels=16,kernel_size=9,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm1d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn2 = nn.Conv1d(in_channels=16,out_channels=20,kernel_size=7,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm1d(20)
        self.maxpool2 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn3 = nn.Conv1d(in_channels=20,out_channels=30,kernel_size=8,stride=6,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm1d(30)
        self.maxpool3 = nn.MaxPool1d(kernel_size=5,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(26*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
mAlexNet_2D_112_s = mAlexNet_2D_112_s_Model()
summary(mAlexNet_2D_112_s,(1,112,112))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 112, 112]             144
#               ReLU-2         [-1, 16, 112, 112]               0
#          MaxPool2d-3           [-1, 16, 56, 56]               0
#             Conv2d-4           [-1, 20, 56, 56]           2,880
#               ReLU-5           [-1, 20, 56, 56]               0
#          MaxPool2d-6           [-1, 20, 28, 28]               0
#             Conv2d-7           [-1, 30, 10, 10]           5,400
#               ReLU-8           [-1, 30, 10, 10]               0
#          MaxPool2d-9             [-1, 30, 5, 5]               0
#           Dropout-10                  [-1, 750]               0
#            Linear-11                   [-1, 60]          45,000
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 54,024
# Trainable params: 54,024
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 4.58
# Params size (MB): 0.21
# Estimated Total Size (MB): 4.83
# ----------------------------------------------------------------

# %%
mAlexNet_1D_12544_s = mAlexNet_1D_12544_s_Model()
summary(mAlexNet_1D_12544_s,(1,12544))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1            [-1, 16, 12536]             144
#               ReLU-2            [-1, 16, 12536]               0
#          MaxPool1d-3             [-1, 16, 3134]               0
#             Conv1d-4             [-1, 20, 3128]           2,240
#               ReLU-5             [-1, 20, 3128]               0
#          MaxPool1d-6              [-1, 20, 782]               0
#             Conv1d-7              [-1, 30, 130]           4,800
#               ReLU-8              [-1, 30, 130]               0
#          MaxPool1d-9               [-1, 30, 26]               0
#           Dropout-10                  [-1, 780]               0
#            Linear-11                   [-1, 60]          46,800
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 54,584
# Trainable params: 54,584
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 4.59
# Params size (MB): 0.21
# Estimated Total Size (MB): 4.85
# ----------------------------------------------------------------

# %% [markdown]
# ## (140,140)

# %%
class mAlexNet_2D_140_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_2D_140_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv2d(in_channels=1,out_channels=16,kernel_size=3,
                                padding=1,bias=False)
        self.bn_1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn2 = nn.Conv2d(in_channels=16,out_channels=20,kernel_size=3,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm2d(20)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn3 = nn.Conv2d(in_channels=20,out_channels=30,kernel_size=3,stride=3,
                                padding=1,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm2d(30)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(6*6*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
class mAlexNet_1D_19600_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_1D_19600_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv1d(in_channels=1,out_channels=16,kernel_size=9,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm1d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn2 = nn.Conv1d(in_channels=16,out_channels=20,kernel_size=7,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm1d(20)
        self.maxpool2 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn3 = nn.Conv1d(in_channels=20,out_channels=30,kernel_size=8,stride=9,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm1d(30)
        self.maxpool3 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(34*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
mAlexNet_2D_140_s = mAlexNet_2D_140_s_Model()
summary(mAlexNet_2D_140_s,(1,140,140))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 140, 140]             144
#               ReLU-2         [-1, 16, 140, 140]               0
#          MaxPool2d-3           [-1, 16, 70, 70]               0
#             Conv2d-4           [-1, 20, 68, 68]           2,880
#               ReLU-5           [-1, 20, 68, 68]               0
#          MaxPool2d-6           [-1, 20, 34, 34]               0
#             Conv2d-7           [-1, 30, 12, 12]           5,400
#               ReLU-8           [-1, 30, 12, 12]               0
#          MaxPool2d-9             [-1, 30, 6, 6]               0
#           Dropout-10                 [-1, 1080]               0
#            Linear-11                   [-1, 60]          64,800
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 73,824
# Trainable params: 73,824
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.07
# Forward/backward pass size (MB): 7.05
# Params size (MB): 0.28
# Estimated Total Size (MB): 7.41
# ----------------------------------------------------------------

# %%
mAlexNet_1D_19600_s = mAlexNet_1D_19600_s_Model()
summary(mAlexNet_1D_19600_s,(1,19600))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1            [-1, 16, 19592]             144
#               ReLU-2            [-1, 16, 19592]               0
#          MaxPool1d-3             [-1, 16, 4898]               0
#             Conv1d-4             [-1, 20, 4892]           2,240
#               ReLU-5             [-1, 20, 4892]               0
#          MaxPool1d-6             [-1, 20, 1223]               0
#             Conv1d-7              [-1, 30, 136]           4,800
#               ReLU-8              [-1, 30, 136]               0
#          MaxPool1d-9               [-1, 30, 34]               0
#           Dropout-10                 [-1, 1020]               0
#            Linear-11                   [-1, 60]          61,200
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 68,984
# Trainable params: 68,984
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.07
# Forward/backward pass size (MB): 7.14
# Params size (MB): 0.26
# Estimated Total Size (MB): 7.48
# ----------------------------------------------------------------

# %% [markdown]
# ## (168,168)

# %%
class mAlexNet_2D_168_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_2D_168_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv2d(in_channels=1,out_channels=16,kernel_size=3,
                                padding=1,bias=False)
        self.bn_1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn2 = nn.Conv2d(in_channels=16,out_channels=20,kernel_size=3,
                                padding=1,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm2d(20)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn3 = nn.Conv2d(in_channels=20,out_channels=30,kernel_size=3,stride=3,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm2d(30)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(7*7*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
class mAlexNet_1D_28224_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_1D_28224_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv1d(in_channels=1,out_channels=16,kernel_size=9,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm1d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn2 = nn.Conv1d(in_channels=16,out_channels=20,kernel_size=7,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm1d(20)
        self.maxpool2 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn3 = nn.Conv1d(in_channels=20,out_channels=30,kernel_size=10,stride=8,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm1d(30)
        self.maxpool3 = nn.MaxPool1d(kernel_size=5,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(44*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
mAlexNet_2D_168_s = mAlexNet_2D_168_s_Model()
summary(mAlexNet_2D_168_s,(1,168,168))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 168, 168]             144
#               ReLU-2         [-1, 16, 168, 168]               0
#          MaxPool2d-3           [-1, 16, 84, 84]               0
#             Conv2d-4           [-1, 20, 84, 84]           2,880
#               ReLU-5           [-1, 20, 84, 84]               0
#          MaxPool2d-6           [-1, 20, 42, 42]               0
#             Conv2d-7           [-1, 30, 14, 14]           5,400
#               ReLU-8           [-1, 30, 14, 14]               0
#          MaxPool2d-9             [-1, 30, 7, 7]               0
#           Dropout-10                 [-1, 1470]               0
#            Linear-11                   [-1, 60]          88,200
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 97,224
# Trainable params: 97,224
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 10.29
# Params size (MB): 0.37
# Estimated Total Size (MB): 10.77
# ----------------------------------------------------------------

# %%
mAlexNet_1D_28224_s = mAlexNet_1D_28224_s_Model()
summary(mAlexNet_1D_28224_s,(1,28224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1            [-1, 16, 28216]             144
#               ReLU-2            [-1, 16, 28216]               0
#          MaxPool1d-3             [-1, 16, 7054]               0
#             Conv1d-4             [-1, 20, 7048]           2,240
#               ReLU-5             [-1, 20, 7048]               0
#          MaxPool1d-6             [-1, 20, 1762]               0
#             Conv1d-7              [-1, 30, 220]           6,000
#               ReLU-8              [-1, 30, 220]               0
#          MaxPool1d-9               [-1, 30, 44]               0
#           Dropout-10                 [-1, 1320]               0
#            Linear-11                   [-1, 60]          79,200
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 88,184
# Trainable params: 88,184
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 10.29
# Params size (MB): 0.34
# Estimated Total Size (MB): 10.74
# ----------------------------------------------------------------

# %% [markdown]
# ## (196,196)

# %%
class mAlexNet_2D_196_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_2D_196_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv2d(in_channels=1,out_channels=16,kernel_size=3,
                                padding=1,bias=False)
        self.bn_1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn2 = nn.Conv2d(in_channels=16,out_channels=20,kernel_size=3,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm2d(20)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn3 = nn.Conv2d(in_channels=20,out_channels=30,kernel_size=3,stride=3,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm2d(30)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(8*8*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
class mAlexNet_1D_38416_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_1D_38416_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv1d(in_channels=1,out_channels=16,kernel_size=9,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm1d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn2 = nn.Conv1d(in_channels=16,out_channels=20,kernel_size=7,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm1d(20)
        self.maxpool2 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn3 = nn.Conv1d(in_channels=20,out_channels=30,kernel_size=7,stride=8,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm1d(30)
        self.maxpool3 = nn.MaxPool1d(kernel_size=5,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(60*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
mAlexNet_2D_196_s = mAlexNet_2D_196_s_Model()
summary(mAlexNet_2D_196_s,(1,196,196))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 196, 196]             144
#               ReLU-2         [-1, 16, 196, 196]               0
#          MaxPool2d-3           [-1, 16, 98, 98]               0
#             Conv2d-4           [-1, 20, 96, 96]           2,880
#               ReLU-5           [-1, 20, 96, 96]               0
#          MaxPool2d-6           [-1, 20, 48, 48]               0
#             Conv2d-7           [-1, 30, 16, 16]           5,400
#               ReLU-8           [-1, 30, 16, 16]               0
#          MaxPool2d-9             [-1, 30, 8, 8]               0
#           Dropout-10                 [-1, 1920]               0
#            Linear-11                   [-1, 60]         115,200
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 124,224
# Trainable params: 124,224
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.15
# Forward/backward pass size (MB): 13.86
# Params size (MB): 0.47
# Estimated Total Size (MB): 14.48
# ----------------------------------------------------------------

# %%
mAlexNet_1D_38416_s = mAlexNet_1D_38416_s_Model()
summary(mAlexNet_1D_38416_s,(1,38416))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1            [-1, 16, 38408]             144
#               ReLU-2            [-1, 16, 38408]               0
#          MaxPool1d-3             [-1, 16, 9602]               0
#             Conv1d-4             [-1, 20, 9596]           2,240
#               ReLU-5             [-1, 20, 9596]               0
#          MaxPool1d-6             [-1, 20, 2399]               0
#             Conv1d-7              [-1, 30, 300]           4,200
#               ReLU-8              [-1, 30, 300]               0
#          MaxPool1d-9               [-1, 30, 60]               0
#           Dropout-10                 [-1, 1800]               0
#            Linear-11                   [-1, 60]         108,000
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 115,184
# Trainable params: 115,184
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.15
# Forward/backward pass size (MB): 14.01
# Params size (MB): 0.44
# Estimated Total Size (MB): 14.60
# ----------------------------------------------------------------

# %% [markdown]
# ## (224,224)

# %%
class mAlexNet_2D_224_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_2D_224_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv2d(in_channels=1,out_channels=16,kernel_size=3,
                                padding=1,bias=False)
        self.bn_1 = nn.BatchNorm2d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn2 = nn.Conv2d(in_channels=16,out_channels=20,kernel_size=3,
                                padding=1,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm2d(20)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        self.cnn3 = nn.Conv2d(in_channels=20,out_channels=30,kernel_size=3,stride=3,
                                padding=2,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm2d(30)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(10*10*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
class mAlexNet_1D_50176_s_Model(nn.Module):
    def __init__(self):
        super(mAlexNet_1D_50176_s_Model,self).__init__()
        
        self.cnn1 = nn.Conv1d(in_channels=1,out_channels=16,kernel_size=9,
                                padding=0,bias=False)
        self.bn_1 = nn.BatchNorm1d(16)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn2 = nn.Conv1d(in_channels=16,out_channels=20,kernel_size=7,
                                padding=0,bias=False)
        self.relu2 = nn.ReLU()
        self.bn_2 = nn.BatchNorm1d(20)
        self.maxpool2 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        self.cnn3 = nn.Conv1d(in_channels=20,out_channels=30,kernel_size=6,stride=8,
                                padding=0,bias=False)
        self.relu3 = nn.ReLU()
        self.bn_3 = nn.BatchNorm1d(30)
        self.maxpool3 = nn.MaxPool1d(kernel_size=4,stride=None)
        
        
        self.drop1 = nn.Dropout(p=0.5)
        
        self.fc1 = nn.Linear(98*30,60,bias=False)
        self.relu4 = nn.ReLU()
        
        self.fc2 = nn.Linear(60,10,bias=False)
        
       
    def forward(self,x):
        x = self.maxpool1(self.relu1(self.cnn1(x)))
        x = self.maxpool2(self.relu2(self.cnn2(x)))
        x = self.maxpool3(self.relu3(self.cnn3(x)))
        
        x = x.view(x.size(0),-1)
        x = self.drop1(x)
        x = self.relu4(self.fc1(x))
        x = self.fc2(x)
        
        return x

# %%
mAlexNet_2D_224_s = mAlexNet_2D_224_s_Model()
summary(mAlexNet_2D_224_s,(1,224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 224, 224]             144
#               ReLU-2         [-1, 16, 224, 224]               0
#          MaxPool2d-3         [-1, 16, 112, 112]               0
#             Conv2d-4         [-1, 20, 112, 112]           2,880
#               ReLU-5         [-1, 20, 112, 112]               0
#          MaxPool2d-6           [-1, 20, 56, 56]               0
#             Conv2d-7           [-1, 30, 20, 20]           5,400
#               ReLU-8           [-1, 30, 20, 20]               0
#          MaxPool2d-9           [-1, 30, 10, 10]               0
#           Dropout-10                 [-1, 3000]               0
#            Linear-11                   [-1, 60]         180,000
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 189,024
# Trainable params: 189,024
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 18.32
# Params size (MB): 0.72
# Estimated Total Size (MB): 19.23
# ----------------------------------------------------------------

# %%
mAlexNet_1D_50176_s = mAlexNet_1D_50176_s_Model()
summary(mAlexNet_1D_50176_s,(1,50176))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1            [-1, 16, 50168]             144
#               ReLU-2            [-1, 16, 50168]               0
#          MaxPool1d-3            [-1, 16, 12542]               0
#             Conv1d-4            [-1, 20, 12536]           2,240
#               ReLU-5            [-1, 20, 12536]               0
#          MaxPool1d-6             [-1, 20, 3134]               0
#             Conv1d-7              [-1, 30, 392]           3,600
#               ReLU-8              [-1, 30, 392]               0
#          MaxPool1d-9               [-1, 30, 98]               0
#           Dropout-10                 [-1, 2940]               0
#            Linear-11                   [-1, 60]         176,400
#              ReLU-12                   [-1, 60]               0
#            Linear-13                   [-1, 10]             600
# ================================================================
# Total params: 182,984
# Trainable params: 182,984
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 18.31
# Params size (MB): 0.70
# Estimated Total Size (MB): 19.20
# ----------------------------------------------------------------
